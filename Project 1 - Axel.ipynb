# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import functions 
from functions import *

# %% [markdown]
# Null Hypothesis (Ho):
# There is no significant difference in behaviour win the Adventure genre when you compare it to the last four decades.
#
# Alternative Hypothesis (Ha):
# The Adventure genre has a different behaviour in comparison to other video game genres over the last four decades.

# %%
df = pd.read_csv(r"C:\Users\Estudiante\Documents\GitHub\First-Project\video game sales all platforms.csv")
df
# Out:
#       Rank                          Title                       Publisher  \
# 0        1                      Minecraft                          Mojang
# 1        2             Grand Theft Auto V                  Rockstar Games
# 2        3  PlayerUnknown's Battlegrounds                PUBG Corporation
# 3        4    The Elder Scrolls V: Skyrim              Bethesda Softworks
# 4        5          Red Dead Redemption 2                  Rockstar Games
# ...    ...                            ...                             ...
# 1029  1030          Football Manager 2022                         Unknown
# 1030  1031            Deltarune Chapter 2                         Unknown
# 1031  1032                      Days Gone  Sony Interactive Entertainment
# 1032  1033                         ARK II                         Unknown
# 1033  1034          Football Manager 2023                         Unknown
#
#                   Developer  Total Sales Release Date Last Update  \
# 0                 Mojang AB  238000000.0   11/18/2011   10/8/2020
# 1            Rockstar North  180000000.0    9/17/2013   10/8/2020
# 2          PUBG Corporation   70000000.0   12/17/2017  10/24/2020
# 3     Bethesda Game Studios   60000000.0   11/10/2011  10/27/2020
# 4          Rockstar Studios   53000000.0   10/26/2018   10/8/2020
# ...                     ...          ...          ...         ...
# 1029     Sports Interactive          NaN          NaN   9/11/2021
# 1030               Toby Fox          NaN          NaN  12/23/2021
# 1031        SIE Bend Studio          NaN    4/26/2019    1/6/2022
# 1032        Studio Wildcard          NaN          NaN   6/13/2022
# 1033     Sports Interactive          NaN          NaN  10/30/2022
#
#                  Genre
# 0     Action-Adventure
# 1     Action-Adventure
# 2              Shooter
# 3         Role-Playing
# 4     Action-Adventure
# ...                ...
# 1029        Simulation
# 1030      Role-Playing
# 1031  Action-Adventure
# 1032  Action-Adventure
# 1033        Simulation
#
# [1034 rows x 8 columns]

# %%
index_dict = {472:'23/3/2021',629:'12/11/2008',643:'9/25/2018',910:'5/4/1994',977:'12/8/2022',1029:'11/8/2021',1030:'9/23/2021',1032:'1/1/2024',1033:'11/7/2022'}

# %%
df = change_year(df,'Release Date',index_dict)

# %%
df
# Out:
#       Rank                          Title                       Publisher  \
# 0        1                      Minecraft                          Mojang
# 1        2             Grand Theft Auto V                  Rockstar Games
# 2        3  PlayerUnknown's Battlegrounds                PUBG Corporation
# 3        4    The Elder Scrolls V: Skyrim              Bethesda Softworks
# 4        5          Red Dead Redemption 2                  Rockstar Games
# ...    ...                            ...                             ...
# 1029  1030          Football Manager 2022                         Unknown
# 1030  1031            Deltarune Chapter 2                         Unknown
# 1031  1032                      Days Gone  Sony Interactive Entertainment
# 1032  1033                         ARK II                         Unknown
# 1033  1034          Football Manager 2023                         Unknown
#
#                   Developer  Total Sales Release Date Last Update  \
# 0                 Mojang AB  238000000.0   11/18/2011   10/8/2020
# 1            Rockstar North  180000000.0    9/17/2013   10/8/2020
# 2          PUBG Corporation   70000000.0   12/17/2017  10/24/2020
# 3     Bethesda Game Studios   60000000.0   11/10/2011  10/27/2020
# 4          Rockstar Studios   53000000.0   10/26/2018   10/8/2020
# ...                     ...          ...          ...         ...
# 1029     Sports Interactive          NaN    11/8/2021   9/11/2021
# 1030               Toby Fox          NaN    9/23/2021  12/23/2021
# 1031        SIE Bend Studio          NaN    4/26/2019    1/6/2022
# 1032        Studio Wildcard          NaN     1/1/2024   6/13/2022
# 1033     Sports Interactive          NaN    11/7/2022  10/30/2022
#
#                  Genre
# 0     Action-Adventure
# 1     Action-Adventure
# 2              Shooter
# 3         Role-Playing
# 4     Action-Adventure
# ...                ...
# 1029        Simulation
# 1030      Role-Playing
# 1031  Action-Adventure
# 1032  Action-Adventure
# 1033        Simulation
#
# [1034 rows x 8 columns]

# %%
df['Total Sales'].isnull().sum()
# Out:
# 24

# %%
df = create_year_column(df,'Release Date','Release Year')

# %%
df
# Out:
#       Rank                          Title                       Publisher  \
# 0        1                      Minecraft                          Mojang
# 1        2             Grand Theft Auto V                  Rockstar Games
# 2        3  PlayerUnknown's Battlegrounds                PUBG Corporation
# 3        4    The Elder Scrolls V: Skyrim              Bethesda Softworks
# 4        5          Red Dead Redemption 2                  Rockstar Games
# ...    ...                            ...                             ...
# 1029  1030          Football Manager 2022                         Unknown
# 1030  1031            Deltarune Chapter 2                         Unknown
# 1031  1032                      Days Gone  Sony Interactive Entertainment
# 1032  1033                         ARK II                         Unknown
# 1033  1034          Football Manager 2023                         Unknown
#
#                   Developer  Total Sales Release Date Last Update  \
# 0                 Mojang AB  238000000.0   2011-11-18   10/8/2020
# 1            Rockstar North  180000000.0   2013-09-17   10/8/2020
# 2          PUBG Corporation   70000000.0   2017-12-17  10/24/2020
# 3     Bethesda Game Studios   60000000.0   2011-11-10  10/27/2020
# 4          Rockstar Studios   53000000.0   2018-10-26   10/8/2020
# ...                     ...          ...          ...         ...
# 1029     Sports Interactive          NaN   2021-11-08   9/11/2021
# 1030               Toby Fox          NaN   2021-09-23  12/23/2021
# 1031        SIE Bend Studio          NaN   2019-04-26    1/6/2022
# 1032        Studio Wildcard          NaN   2024-01-01   6/13/2022
# 1033     Sports Interactive          NaN   2022-11-07  10/30/2022
#
#                  Genre  Release Year
# 0     Action-Adventure        2011.0
# 1     Action-Adventure        2013.0
# 2              Shooter        2017.0
# 3         Role-Playing        2011.0
# 4     Action-Adventure        2018.0
# ...                ...           ...
# 1029        Simulation        2021.0
# 1030      Role-Playing        2021.0
# 1031  Action-Adventure        2019.0
# 1032  Action-Adventure        2024.0
# 1033        Simulation        2022.0
#
# [1034 rows x 9 columns]

# %%
genre_sales_df = genre_sales_df(df,'Genre', 'Release Year','Total Sales','genre_sales','Genre Category','Adventure')

# %%
genre_sales_df
# Out:
#         Genre  Release Year  Total Sales Genre Category
# 0      Action        1995.0     250000.0          Other
# 1      Action        1997.0    1500000.0          Other
# 2      Action        1999.0     300000.0          Other
# 3      Action        2002.0    4000000.0          Other
# 4      Action        2003.0    2000000.0          Other
# ..        ...           ...          ...            ...
# 362  Strategy        2017.0     130000.0          Other
# 363  Strategy        2019.0     500000.0          Other
# 364  Strategy        2020.0     600000.0          Other
# 365  Strategy        2022.0     660000.0          Other
# 366  Strategy        2023.0     250000.0          Other
#
# [367 rows x 4 columns]

# %%
adventure_sales_df = selected_genre_sales_df(genre_sales_df,'Genre','Adventure')

# %%
adventure_sales_df
# Out:
#         Genre  Release Year  Total Sales Genre Category
# 61  Adventure        1980.0      30000.0      Adventure
# 62  Adventure        1982.0     500000.0      Adventure
# 63  Adventure        1984.0     100000.0      Adventure
# 64  Adventure        1986.0     400000.0      Adventure
# 65  Adventure        1987.0     250000.0      Adventure
# 66  Adventure        1988.0     230000.0      Adventure
# 67  Adventure        1989.0     100000.0      Adventure
# 68  Adventure        1990.0     500000.0      Adventure
# 69  Adventure        1991.0     380000.0      Adventure
# 70  Adventure        1992.0     700000.0      Adventure
# 71  Adventure        1993.0    2700000.0      Adventure
# 72  Adventure        1994.0     300000.0      Adventure
# 73  Adventure        1995.0    1700000.0      Adventure
# 74  Adventure        1996.0    1800000.0      Adventure
# 75  Adventure        1997.0    1600000.0      Adventure
# 76  Adventure        1998.0     150000.0      Adventure
# 77  Adventure        1999.0    2900000.0      Adventure
# 78  Adventure        2000.0    1020000.0      Adventure
# 79  Adventure        2001.0    1500000.0      Adventure
# 80  Adventure        2002.0     500000.0      Adventure
# 81  Adventure        2003.0          0.0      Adventure
# 82  Adventure        2004.0     900000.0      Adventure
# 83  Adventure        2005.0     240000.0      Adventure
# 84  Adventure        2006.0     300000.0      Adventure
# 85  Adventure        2008.0      30000.0      Adventure
# 86  Adventure        2010.0    6660000.0      Adventure
# 87  Adventure        2011.0    5000000.0      Adventure
# 88  Adventure        2013.0     820000.0      Adventure
# 89  Adventure        2014.0    3800000.0      Adventure
# 90  Adventure        2015.0    3000000.0      Adventure
# 91  Adventure        2016.0    4100000.0      Adventure
# 92  Adventure        2018.0   14230000.0      Adventure
# 93  Adventure        2019.0    1500000.0      Adventure
# 94  Adventure        2020.0     900000.0      Adventure
# 95  Adventure        2021.0     500000.0      Adventure
# 96  Adventure        2022.0    1000000.0      Adventure
# 97  Adventure        2023.0     120000.0      Adventure

# %%
total_sales_graph('Release Year', 'Total Sales',adventure_sales_df, 'Adventure' )

# %%
all_genres_vs_one_genre_graph(genre_sales_df,'Release Year','Total Sales','Genre Category','Adventure')

# %%
type(genre_sales)
